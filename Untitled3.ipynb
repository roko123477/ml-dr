# %%
import os
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix
import itertools

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# datagen = ImageDataGenerator(
#         rotation_range=45,     #Random rotation between 0 and 45
#         width_shift_range=0.2,   #% shift
#         height_shift_range=0.2,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
#         fill_mode='reflect')

# %%
Healthy = os.listdir('C:/Users/rohit/Downloads/archive (3)/Healthy')
Mild = os.listdir('C:/Users/rohit/Downloads/archive (3)/Mild DR')
Moderate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Moderate DR')
Proliferate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Proliferate DR')
Severe = os.listdir('C:/Users/rohit/Downloads/archive (3)/Severe DR')

# %%
img_w, img_h = 256, 256
X = []
y = []

# %%
for i in Healthy:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Healthy/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(0)
    except UnidentifiedImageError:
        pass

# %%
for i in Mild:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Mild DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(1)
    except UnidentifiedImageError:
        pass

# %%
for i in Moderate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Moderate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(2)
    except UnidentifiedImageError:
        pass

# %%
for i in Proliferate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Proliferate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(3)
    except UnidentifiedImageError:
        pass

# %%
for i in Severe:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Severe DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(4)
    except UnidentifiedImageError:
        pass

# %%
X = np.asarray(X)
y = np.asarray(y)
print(X.shape, y.shape)
# Out:
# (7292, 256, 256, 3) (7292,)

# %%
x = X.astype('float32')
x /= 255

# %%
num_classes = 5

labels = keras.utils.to_categorical(y, num_classes)
print(labels[0])
# Out:
# [1. 0. 0. 0. 0.]

# %%
x_train1, x_test, y_train1, y_test = train_test_split(x, labels, test_size = 0.1, random_state=5)
x_train,x_val,y_train,y_val=train_test_split(x_train1,y_train1,test_size=0.1,random_state=5)

print('Number of train: {}'.format(len(x_train)))
print('Number of validation: {}'.format(len(x_val)))
print('Number of test: {}'.format(len(x_test)))
# Out:
# Number of train: 5905
# Number of validation: 657
# Number of test: 730

# %%
len(x_train)
# Out:
# 5905

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     rotation_range=20.,
#     width_shift_range=0.5,
#     height_shift_range=0.5,
#     shear_range=30.,
#     zoom_range=4.,
#     channel_shift_range=0.,
#     fill_mode='nearest',
#     cval=0.,
#     horizontal_flip=0.2,
#     vertical_flip=0.2,
#     rescale=None)

# datagen.fit(x_train)

# %%
base_model = tf.keras.applications.InceptionV3(input_shape=(256,256,3),include_top=False,weights="imagenet",pooling='max')

# %%
for layer in base_model.layers[:-10]:
    layer.trainable=True

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(5, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  dropout (Dropout)           (None, 2048)              0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 22,082,213
# Trainable params: 22,047,781
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 3*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'recall',patience = 10,verbose = 1,factor = 0.50, min_lr = 1e-6)
es = EarlyStopping(verbose=1, patience=10)

# %%
model.compile(optimizer='Adamax', loss = tf.keras.losses.CategoricalCrossentropy(),metrics=METRICS)

# %%
# %time
history=model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs = 25,verbose = 1,callbacks=[lrd,es])
# Out:
# Wall time: 0 ns
# Epoch 1/27
# 370/370 [==============================] - 43s 82ms/step - loss: 1.1369 - accuracy: 0.5140 - precision: 0.6344 - recall: 0.2957 - auc: 0.8337 - f1_score: 0.5752 - val_loss: 0.8970 - val_accuracy: 0.6088 - val_precision: 0.7044 - val_recall: 0.4353 - val_auc: 0.8981 - val_f1_score: 0.8180 - lr: 0.0010
# Epoch 2/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.8158 - accuracy: 0.6605 - precision: 0.7186 - recall: 0.5597 - auc: 0.9136 - f1_score: 0.9369 - val_loss: 0.8121 - val_accuracy: 0.6377 - val_precision: 0.6972 - val_recall: 0.5327 - val_auc: 0.9126 - val_f1_score: 0.8836 - lr: 0.0010
# Epoch 3/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.6722 - accuracy: 0.7290 - precision: 0.7627 - recall: 0.6799 - auc: 0.9409 - f1_score: 1.0737 - val_loss: 0.7407 - val_accuracy: 0.6819 - val_precision: 0.7096 - val_recall: 0.6545 - val_auc: 0.9266 - val_f1_score: 0.9980 - lr: 0.0010
# Epoch 4/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.5794 - accuracy: 0.7714 - precision: 0.8001 - recall: 0.7368 - auc: 0.9559 - f1_score: 1.1459 - val_loss: 0.7650 - val_accuracy: 0.7230 - val_precision: 0.7389 - val_recall: 0.7108 - val_auc: 0.9330 - val_f1_score: 1.0628 - lr: 0.0010
# Epoch 5/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.4402 - accuracy: 0.8340 - precision: 0.8547 - recall: 0.8151 - auc: 0.9735 - f1_score: 1.2475 - val_loss: 0.8223 - val_accuracy: 0.7154 - val_precision: 0.7360 - val_recall: 0.7002 - val_auc: 0.9261 - val_f1_score: 1.0510 - lr: 0.0010
# Epoch 6/27
# 370/370 [==============================] - 28s 77ms/step - loss: 0.3580 - accuracy: 0.8672 - precision: 0.8788 - recall: 0.8544 - auc: 0.9819 - f1_score: 1.2996 - val_loss: 0.6683 - val_accuracy: 0.7747 - val_precision: 0.7863 - val_recall: 0.7504 - val_auc: 0.9475 - val_f1_score: 1.1249 - lr: 0.0010
# Epoch 7/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.2749 - accuracy: 0.8986 - precision: 0.9082 - recall: 0.8896 - auc: 0.9887 - f1_score: 1.3482 - val_loss: 0.9177 - val_accuracy: 0.7352 - val_precision: 0.7369 - val_recall: 0.7291 - val_auc: 0.9324 - val_f1_score: 1.1081 - lr: 0.0010
# Epoch 8/27
# 370/370 [==============================] - 29s 78ms/step - loss: 0.2272 - accuracy: 0.9214 - precision: 0.9270 - recall: 0.9165 - auc: 0.9918 - f1_score: 1.3788 - val_loss: 0.9917 - val_accuracy: 0.6804 - val_precision: 0.6976 - val_recall: 0.6636 - val_auc: 0.9078 - val_f1_score: 1.0299 - lr: 0.0010
# Epoch 9/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.1781 - accuracy: 0.9394 - precision: 0.9432 - recall: 0.9365 - auc: 0.9943 - f1_score: 1.4098 - val_loss: 0.7256 - val_accuracy: 0.7778 - val_precision: 0.7797 - val_recall: 0.7702 - val_auc: 0.9459 - val_f1_score: 1.1362 - lr: 0.0010
# Epoch 10/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0
27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.0135 - accuracy: 0.9953 - precision: 0.9954 - recall: 0.9948 - auc: 0.9999 - f1_score: 1.4926 - val_loss: 1.0589 - val_accuracy: 0.7976 - val_precision: 0.8009 - val_recall: 0.7960 - val_auc: 0.9370 - val_f1_score: 1.1707 - lr: 5.0000e-04
# Epoch 19/27
# 370/370 [==============================] - 29s 77ms/step - loss: 0.0221 - accuracy: 0.9932 - precision: 0.9936 - recall: 0.9931 - auc: 0.9996 - f1_score: 1.4899 - val_loss: 0.9136 - val_accuracy: 0.7991 - val_precision: 0.8034 - val_recall: 0.7960 - val_auc: 0.9435 - val_f1_score: 1.1730 - lr: 5.0000e-04
# Epoch 20/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0142 - accuracy: 0.9941 - precision: 0.9942 - recall: 0.9937 - auc: 0.9999 - f1_score: 1.4872 - val_loss: 0.9560 - val_accuracy: 0.7991 - val_precision: 0.8031 - val_recall: 0.7945 - val_auc: 0.9403 - val_f1_score: 1.1712 - lr: 5.0000e-04
# Epoch 21/27
# 369/370 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9966 - precision: 0.9966 - recall: 0.9963 - auc: 1.0000 - f1_score: 1.4947
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0089 - accuracy: 0.9964 - precision: 0.9964 - recall: 0.9961 - auc: 0.9999 - f1_score: 1.4906 - val_loss: 0.9263 - val_accuracy: 0.8082 - val_precision: 0.8123 - val_recall: 0.8037 - val_auc: 0.9421 - val_f1_score: 1.1847 - lr: 5.0000e-04
# Epoch 22/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0072 - accuracy: 0.9968 - precision: 0.9970 - recall: 0.9964 - auc: 1.0000 - f1_score: 1.4950 - val_loss: 0.9786 - val_accuracy: 0.8052 - val_precision: 0.8064 - val_recall: 0.8052 - val_auc: 0.9410 - val_f1_score: 1.1815 - lr: 2.5000e-04
# Epoch 23/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0073 - accuracy: 0.9966 - precision: 0.9966 - recall: 0.9966 - auc: 1.0000 - f1_score: 1.4949 - val_loss: 1.0085 - val_accuracy: 0.8037 - val_precision: 0.8052 - val_recall: 0.7991 - val_auc: 0.9349 - val_f1_score: 1.1764 - lr: 2.5000e-04
# Epoch 24/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0094 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9951 - auc: 1.0000 - f1_score: 1.4890 - val_loss: 0.9908 - val_accuracy: 0.8037 - val_precision: 0.8086 - val_recall: 0.8037 - val_auc: 0.9350 - val_f1_score: 1.1821 - lr: 2.5000e-04
# Epoch 25/27
# 370/370 [==============================] - 28s 77ms/step - loss: 0.0071 - accuracy: 0.9961 - precision: 0.9964 - recall: 0.9961 - auc: 1.0000 - f1_score: 1.4906 - val_loss: 0.9613 - val_accuracy: 0.8037 - val_precision: 0.8061 - val_recall: 0.8037 - val_auc: 0.9394 - val_f1_score: 1.1806 - lr: 2.5000e-04
# Epoch 26/27
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0064 - accuracy: 0.9975 - precision: 0.9976 - recall: 0.9971 - auc: 1.0000 - f1_score: 1.4923 - val_loss: 1.0055 - val_accuracy: 0.8082 - val_precision: 0.8107 - val_recall: 0.8082 - val_auc: 0.9366 - val_f1_score: 1.1870 - lr: 2.5000e-04
# Epoch 26: early stopping

# %%
score = model.evaluate(x_test, y_test,  verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8246575593948364

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
