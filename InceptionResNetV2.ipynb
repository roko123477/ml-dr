# %%
import os
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix
import itertools

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# datagen = ImageDataGenerator(
#         rotation_range=45,     #Random rotation between 0 and 45
#         width_shift_range=0.2,   #% shift
#         height_shift_range=0.2,
#         shear_range=0.2,
#         zoom_range=0.3,
#         horizontal_flip=True,
#         fill_mode='reflect')

# %%
Healthy = os.listdir('C:/Users/rohit/Downloads/archive (3)/Healthy')
Mild = os.listdir('C:/Users/rohit/Downloads/archive (3)/Mild DR')
Moderate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Moderate DR')
Proliferate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Proliferate DR')
Severe = os.listdir('C:/Users/rohit/Downloads/archive (3)/Severe DR')

# %%
img_w, img_h = 256, 256
X = []
y = []

# %%
# x = x.reshape((1, ) + x.shape)  #Array with shape (1, 256, 256, 3)

# i = 0
# for batch in datagen.flow(x, batch_size=16,  
#                           save_to_dir='augmented', 
#                           save_prefix='aug', 
#                           save_format='png'):
#     i += 1
#     if i > 20:
#         break

# %%
for i in Healthy:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Healthy/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(0)
    except UnidentifiedImageError:
        pass

# %%
for i in Mild:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Mild DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        x=np.asarray(img)
        X.append(np.asarray(img))
        y.append(1)
    except UnidentifiedImageError:
        pass

# %%
for i in Moderate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Moderate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(2)
    except UnidentifiedImageError:
        pass

# %%
for i in Proliferate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Proliferate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(3)
    except UnidentifiedImageError:
        pass

# %%
for i in Severe:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Severe DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(4)
    except UnidentifiedImageError:
        pass

# %%
X = np.asarray(X)
y = np.asarray(y)
print(X.shape, y.shape)
# Out:
# (7391, 256, 256, 3) (7391,)

# %%
x = X.astype('float32')
x /= 255

# %%
num_classes = 5

labels = keras.utils.to_categorical(y, num_classes)
print(labels[0])
# Out:
# [1. 0. 0. 0. 0.]

# %%
x_train1, x_test, y_train1, y_test = train_test_split(x, labels, test_size = 0.1, random_state=42)
x_train,x_val,y_train,y_val=train_test_split(x_train1,y_train1,test_size=0.1,random_state=42)

print('Number of train: {}'.format(len(x_train)))
print('Number of validation: {}'.format(len(x_val)))
print('Number of test: {}'.format(len(x_test)))
# Out:
# Number of train: 5985
# Number of validation: 666
# Number of test: 740

# %%
len(x_train)
# Out:
# 5985

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     rotation_range=20.,
#     width_shift_range=0.5,
#     height_shift_range=0.5,
#     shear_range=30.,
#     zoom_range=4.,
#     channel_shift_range=0.,
#     fill_mode='nearest',
#     cval=0.,
#     horizontal_flip=0.2,
#     vertical_flip=0.2,
#     rescale=None)

# datagen.fit(x_train)

# %%
base_model = tf.keras.applications.InceptionResNetV2(input_shape=(256,256,3),include_top=False,weights="imagenet",pooling='max')

# %%
for layer in base_model.layers[:-11]:
    layer.trainable=True

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(5, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 1536)             54336736
#  onal)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 128)               196736
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 54,550,629
# Trainable params: 54,490,085
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 3*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'recall',patience = 10,verbose = 1,factor = 0.50, min_lr = 1e-7)
# es = EarlyStopping(verbose=1, patience=20,monitor='val_accuracy')

# %%
model.compile(optimizer='Adamax', loss = tf.keras.losses.CategoricalCrossentropy(),metrics=METRICS)

# %%
# %time
history=model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs = 50,verbose = 1,callbacks=[lrd],batch_size=16)
# Out:
# Wall time: 0 ns
# Epoch 1/50
# 375/375 [==============================] - 83s 183ms/step - loss: 0.9404 - accuracy: 0.5975 - precision: 0.6739 - recall: 0.4899 - auc: 0.8864 - f1_score: 0.8327 - val_loss: 0.8158 - val_accuracy: 0.6562 - val_precision: 0.6924 - val_recall: 0.5916 - val_auc: 0.9180 - val_f1_score: 0.9570 - lr: 0.0010
# Epoch 2/50
# 375/375 [==============================] - 63s 169ms/step - loss: 0.6590 - accuracy: 0.7263 - precision: 0.7621 - recall: 0.6712 - auc: 0.9425 - f1_score: 1.0657 - val_loss: 0.7436 - val_accuracy: 0.7372 - val_precision: 0.7766 - val_recall: 0.6577 - val_auc: 0.9319 - val_f1_score: 1.0667 - lr: 0.0010
# Epoch 3/50
# 375/375 [==============================] - 64s 170ms/step - loss: 0.5199 - accuracy: 0.7935 - precision: 0.8159 - recall: 0.7657 - auc: 0.9638 - f1_score: 1.1805 - val_loss: 0.6260 - val_accuracy: 0.7553 - val_precision: 0.7743 - val_recall: 0.7417 - val_auc: 0.9493 - val_f1_score: 1.1343 - lr: 0.0010
# Epoch 4/50
# 375/375 [==============================] - 63s 167ms/step - loss: 0.3922 - accuracy: 0.8458 - precision: 0.8594 - recall: 0.8292 - auc: 0.9788 - f1_score: 1.2620 - val_loss: 1.3776 - val_accuracy: 0.6502 - val_precision: 0.6661 - val_recall: 0.6321 - val_auc: 0.8895 - val_f1_score: 0.9750 - lr: 0.0010
# Epoch 5/50
# 375/375 [==============================] - 65s 172ms/step - loss: 0.2689 - accuracy: 0.8997 - precision: 0.9068 - recall: 0.8864 - auc: 0.9891 - f1_score: 1.3446 - val_loss: 1.0701 - val_accuracy: 0.7312 - val_precision: 0.7423 - val_recall: 0.7267 - val_auc: 0.9226 - val_f1_score: 1.1020 - lr: 0.0010
# Epoch 6/50
# 375/375 [==============================] - 64s 171ms/step - loss: 0.1955 - accuracy: 0.9283 - precision: 0.9335 - recall: 0.9246 - auc: 0.9937 - f1_score: 1.3897 - val_loss: 0.8436 - val_accuracy: 0.7913 - val_precision: 0.7982 - val_recall: 0.7898 - val_auc: 0.9388 - val_f1_score: 1.1921 - lr: 0.0010
- recall: 0.9957 - auc: 1.0000 - f1_score: 1.4940 - val_loss: 0.8672 - val_accuracy: 0.8228 - val_precision: 0.8226 - val_recall: 0.8213 - val_auc: 0.9484 - val_f1_score: 1.2340 - lr: 2.5000e-04
# Epoch 24/50
# 375/375 [==============================] - 64s 170ms/step - loss: 0.0071 - accuracy: 0.9963 - precision: 0.9965 - recall: 0.9960 - auc: 1.0000 - f1_score: 1.4944 - val_loss: 0.9488 - val_accuracy: 0.8198 - val_precision: 0.8198 - val_recall: 0.8198 - val_auc: 0.9477 - val_f1_score: 1.2308 - lr: 2.5000e-04
# Epoch 25/50
# 375/375 [==============================] - 64s 170ms/step - loss: 0.0081 - accuracy: 0.9957 - precision: 0.9960 - recall: 0.9957 - auc: 0.9999 - f1_score: 1.4900 - val_loss: 0.8840 - val_accuracy: 0.8153 - val_precision: 0.8163 - val_recall: 0.8138 - val_auc: 0.9474 - val_f1_score: 1.2240 - lr: 2.5000e-04
# Epoch 26/50
# 375/375 [==============================] - 64s 170ms/step - loss: 0.0072 - accuracy: 0.9953 - precision: 0.9963 - recall: 0.9945 - auc: 1.0000 - f1_score: 1.4893 - val_loss: 0.9021 - val_accuracy: 0.8243 - val_precision: 0.8241 - val_recall: 0.8228 - val_auc: 0.9483 - val_f1_score: 1.2361 - lr: 2.5000e-04
# Epoch 27/50
# 375/375 [==============================] - 64s 171ms/step - loss: 0.0065 - accuracy: 0.9965 - precision: 0.9968 - recall: 0.9963 - auc: 1.0000 - f1_score: 1.4949 - val_loss: 0.8995 - val_accuracy: 0.8168 - val_precision: 0.8165 - val_recall: 0.8153 - val_auc: 0.9486 - val_f1_score: 1.2251 - lr: 2.5000e-04
# Epoch 28/50
# 375/375 [==============================] - 65s 173ms/step - loss: 0.0070 - accuracy: 0.9957 - precision: 0.9958 - recall: 0.9953 - auc: 1.0000 - f1_score: 1.4934 - val_loss: 0.8850 - val_accuracy: 0.8243 - val_precision: 0.8256 - val_recall: 0.8243 - val_auc: 0.9495 - val_f1_score: 1.2385 - lr: 2.5000e-04
# Epoch 29/50
# 375/375 [==============================] - 63s 169ms/step - loss: 0.0063 - accuracy: 0.9960 - precision: 0.9963 - recall: 0.9960 - auc: 1.0000 - f1_score: 1.4942 - val_loss: 0.9134 - val_accuracy: 0.8213 - val_precision: 0.8213 - val_recall: 0.8213 - val_auc: 0.9448 - val_f1_score: 1.2330 - lr: 2.5000e-04
# Epoch 30/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0072 - accuracy: 0.9953 - precision: 0.9957 - recall: 0.9950 - auc: 1.0000 - f1_score: 1.4892 - val_loss: 0.8586 - val_accuracy: 0.8273 - val_precision: 0.8286 - val_recall: 0.8273 - val_auc: 0.9474 - val_f1_score: 1.2425 - lr: 2.5000e-04
# Epoch 31/50
# 375/375 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9958 - precision: 0.9962 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4900
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0064 - accuracy: 0.9958 - precision: 0.9962 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4900 - val_loss: 0.9141 - val_accuracy: 0.8288 - val_precision: 0.8313 - val_recall: 0.8288 - val_auc: 0.9447 - val_f1_score: 1.2462 - lr: 2.5000e-04
# Epoch 32/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0067 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9955 - auc: 1.0000 - f1_score: 1.4899 - val_loss: 0.9243 - val_accuracy: 0.8273 - val_precision: 0.8281 - val_recall: 0.8243 - val_auc: 0.9477 - val_f1_score: 1.2405 - lr: 1.2500e-04
# Epoch 33/50
# 375/375 [==============================] - 62s 167ms/step - loss: 0.0067 - accuracy: 0.9962 - precision: 0.9963 - recall: 0.9960 - auc: 0.9999 - f1_score: 1.4905 - val_loss: 0.8990 - val_accuracy: 0.8243 - val_precision: 0.8243 - val_recall: 0.8243 - val_auc: 0.9464 - val_f1_score: 1.2375 - lr: 1.2500e-04
# Epoch 34/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0055 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9968 - auc: 1.0000 - f1_score: 1.4956 - val_loss: 0.9267 - val_accuracy: 0.8243 - val_precision: 0.8256 - val_recall: 0.8243 - val_auc: 0.9467 - val_f1_score: 1.2386 - lr: 1.2500e-04
# Epoch 35/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0055 - accuracy: 0.9967 - precision: 0.9968 - recall: 0.9963 - auc: 1.0000 - f1_score: 1.4911 - val_loss: 0.9162 - val_accuracy: 0.8228 - val_precision: 0.8226 - val_recall: 0.8213 - val_auc: 0.9471 - val_f1_score: 1.2341 - lr: 1.2500e-04
# Epoch 36/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0054 - accuracy: 0.9968 - precision: 0.9968 - recall: 0.9967 - auc: 1.0000 - f1_score: 1.4914 - val_loss: 0.9358 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_auc: 0.9451 - val_f1_score: 1.2353 - lr: 1.2500e-04
# Epoch 37/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0057 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9965 - auc: 1.0000 - f1_score: 1.4914 - val_loss: 0.9381 - val_accuracy: 0.8198 - val_precision: 0.8208 - val_recall: 0.8183 - val_auc: 0.9460 - val_f1_score: 1.2304 - lr: 1.2500e-04
# Epoch 38/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0068 - accuracy: 0.9972 - precision: 0.9973 - recall: 0.9968 - auc: 0.9999 - f1_score: 1.4919 - val_loss: 0.9481 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_auc: 0.9468 - val_f1_score: 1.2353 - lr: 1.2500e-04
# Epoch 39/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0057 - accuracy: 0.9970 - precision: 0.9970 - recall: 0.9967 - auc: 1.0000 - f1_score: 1.4915 - val_loss: 0.9506 - val_accuracy: 0.8258 - val_precision: 0.8283 - val_recall: 0.8258 - val_auc: 0.9454 - val_f1_score: 1.2415 - lr: 1.2500e-04
# Epoch 40/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0051 - accuracy: 0.9972 - precision: 0.9973 - recall: 0.9968 - auc: 1.0000 - f1_score: 1.4917 - val_loss: 0.9342 - val_accuracy: 0.8243 - val_precision: 0.8243 - val_recall: 0.8243 - val_auc: 0.9449 - val_f1_score: 1.2375 - lr: 1.2500e-04
# Epoch 41/50
# 375/375 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9963 - precision: 0.9968 - recall: 0.9963 - auc: 1.0000 - f1_score: 1.4949
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0053 - accuracy: 0.9963 - precision: 0.9968 - recall: 0.9963 - auc: 1.0000 - f1_score: 1.4949 - val_loss: 0.9446 - val_accuracy: 0.8213 - val_precision: 0.8226 - val_recall: 0.8213 - val_auc: 0.9437 - val_f1_score: 1.2339 - lr: 1.2500e-04
# Epoch 42/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0068 - accuracy: 0.9967 - precision: 0.9968 - recall: 0.9965 - auc: 0.9999 - f1_score: 1.4911 - val_loss: 0.9499 - val_accuracy: 0.8258 - val_precision: 0.8283 - val_recall: 0.8258 - val_auc: 0.9448 - val_f1_score: 1.2417 - lr: 6.2500e-05
# Epoch 43/50
# 375/375 [==============================] - 62s 165ms/step - loss: 0.0055 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9968 - auc: 1.0000 - f1_score: 1.4919 - val_loss: 0.9452 - val_accuracy: 0.8273 - val_precision: 0.8281 - val_recall: 0.8243 - val_auc: 0.9441 - val_f1_score: 1.2405 - lr: 6.2500e-05
# Epoch 44/50
# 375/375 [==============================] - 61s 164ms/step - loss: 0.0061 - accuracy: 0.9967 - precision: 0.9970 - recall: 0.9965 - auc: 0.9999 - f1_score: 1.4914 - val_loss: 0.9513 - val_accuracy: 0.8258 - val_precision: 0.8271 - val_recall: 0.8258 - val_auc: 0.9447 - val_f1_score: 1.2406 - lr: 6.2500e-05
# Epoch 45/50
# 375/375 [==============================] - 62s 164ms/step - loss: 0.0055 - accuracy: 0.9968 - precision: 0.9972 - recall: 0.9968 - auc: 1.0000 - f1_score: 1.4916 - val_loss: 0.9610 - val_accuracy: 0.8243 - val_precision: 0.8256 - val_recall: 0.8243 - val_auc: 0.9443 - val_f1_score: 1.2384 - lr: 6.2500e-05
# Epoch 46/50
# 375/375 [==============================] - 61s 163ms/step - loss: 0.0054 - accuracy: 0.9970 - precision: 0.9975 - recall: 0.9967 - auc: 1.0000 - f1_score: 1.4917 - val_loss: 0.9619 - val_accuracy: 0.8228 - val_precision: 0.8241 - val_recall: 0.8228 - val_auc: 0.9446 - val_f1_score: 1.2361 - lr: 6.2500e-05
# Epoch 47/50
# 375/375 [==============================] - 61s 163ms/step - loss: 0.0053 - accuracy: 0.9970 - precision: 0.9975 - recall: 0.9970 - auc: 1.0000 - f1_score: 1.4959 - val_loss: 0.9591 - val_accuracy: 0.8273 - val_precision: 0.8273 - val_recall: 0.8273 - val_auc: 0.9449 - val_f1_score: 1.2420 - lr: 6.2500e-05
# Epoch 48/50
# 375/375 [==============================] - 61s 164ms/step - loss: 0.0053 - accuracy: 0.9972 - precision: 0.9975 - recall: 0.9972 - auc: 1.0000 - f1_score: 1.4922 - val_loss: 0.9487 - val_accuracy: 0.8288 - val_precision: 0.8288 - val_recall: 0.8288 - val_auc: 0.9444 - val_f1_score: 1.2442 - lr: 6.2500e-05
# Epoch 49/50
# 375/375 [==============================] - 61s 163ms/step - loss: 0.0049 - accuracy: 0.9970 - precision: 0.9975 - recall: 0.9965 - auc: 1.0000 - f1_score: 1.4916 - val_loss: 0.9588 - val_accuracy: 0.8318 - val_precision: 0.8331 - val_recall: 0.8318 - val_auc: 0.9445 - val_f1_score: 1.2497 - lr: 6.2500e-05
# Epoch 50/50
# 375/375 [==============================] - 61s 164ms/step - loss: 0.0058 - accuracy: 0.9957 - precision: 0.9963 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4901 - val_loss: 0.9504 - val_accuracy: 0.8213 - val_precision: 0.8238 - val_recall: 0.8213 - val_auc: 0.9449 - val_f1_score: 1.2347 - lr: 6.2500e-05

# %%
score = model.evaluate(x_test, y_test,  verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8391891717910767

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['precision'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
