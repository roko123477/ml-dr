# %%
import os
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix
import itertools

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\rohit\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# datagen = ImageDataGenerator(
#         rotation_range=45,     #Random rotation between 0 and 45
#         width_shift_range=0.2,   #% shift
#         height_shift_range=0.2,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
#         fill_mode='reflect')

# %%
Healthy = os.listdir('C:/Users/rohit/Downloads/archive (3)/Healthy')
Mild = os.listdir('C:/Users/rohit/Downloads/archive (3)/Mild DR')
Moderate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Moderate DR')
Proliferate = os.listdir('C:/Users/rohit/Downloads/archive (3)/Proliferate DR')
Severe = os.listdir('C:/Users/rohit/Downloads/archive (3)/Severe DR')

# %%
img_w, img_h = 256, 256
X = []
y = []

# %%
for i in Healthy:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Healthy/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        
        X.append(np.asarray(img))
        y.append(0)
    except UnidentifiedImageError:
        pass

# %%
for i in Mild:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Mild DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(1)
    except UnidentifiedImageError:
        pass

# %%
for i in Moderate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Moderate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(2)
    except UnidentifiedImageError:
        pass

# %%
for i in Proliferate:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Proliferate DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(3)
    except UnidentifiedImageError:
        pass

# %%
for i in Severe:
    try:
        img = Image.open("C:/Users/rohit/Downloads/archive (3)/Severe DR/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(4)
    except UnidentifiedImageError:
        pass

# %%
X = np.asarray(X)
y = np.asarray(y)
print(X.shape, y.shape)
# Out:
# (6267, 256, 256, 3) (6267,)

# %%
x = X.astype('float32')
x /= 255

# %%
num_classes = 5

labels = keras.utils.to_categorical(y, num_classes)
print(labels[0])
# Out:
# [1. 0. 0. 0. 0.]

# %%
x_train1, x_test, y_train1, y_test = train_test_split(x, labels, test_size = 0.1, random_state=5)
x_train,x_val,y_train,y_val=train_test_split(x_train1,y_train1,test_size=0.1,random_state=5)

print('Number of train: {}'.format(len(x_train)))
print('Number of validation: {}'.format(len(x_val)))
print('Number of test: {}'.format(len(x_test)))
# Out:
# Number of train: 5076
# Number of validation: 564
# Number of test: 627

# %%
len(x_train)
# Out:
# 5076

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     rotation_range=20.,
#     width_shift_range=0.5,
#     height_shift_range=0.5,
#     shear_range=30.,
#     zoom_range=4.,
#     channel_shift_range=0.,
#     fill_mode='nearest',
#     cval=0.,
#     horizontal_flip=0.2,
#     vertical_flip=0.2,
#     rescale=None)

# datagen.fit(x_train)

# %%
base_model = tf.keras.applications.Xception(input_shape=(256,256,3),include_top=False,weights="imagenet",pooling='max')

# %%
for layer in base_model.layers[:-15]:
    layer.trainable=True

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(128, activation='relu'))
model.add(Dense(5, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dropout (Dropout)           (None, 2048)              0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 21,140,909
# Trainable params: 21,086,381
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 3*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'recall',patience = 10,verbose = 1,factor = 0.50, min_lr = 1e-8)
# es = EarlyStopping(verbose=1, patience=20)

# %%
model.compile(optimizer='Adamax', loss = tf.keras.losses.CategoricalCrossentropy(),metrics=METRICS)

# %%
# %time
history=model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs = 50,verbose = 1,callbacks=[lrd],batch_size=16)
# Out:
# Wall time: 0 ns
# Epoch 1/50
# 318/318 [==============================] - 57s 160ms/step - loss: 0.9570 - accuracy: 0.5999 - precision: 0.6970 - recall: 0.4500 - auc: 0.8824 - f1_score: 0.7870 - val_loss: 0.8480 - val_accuracy: 0.6596 - val_precision: 0.6980 - val_recall: 0.6188 - val_auc: 0.9121 - val_f1_score: 0.9883 - lr: 0.0010
# Epoch 2/50
# 318/318 [==============================] - 50s 157ms/step - loss: 0.6359 - accuracy: 0.7591 - precision: 0.7996 - recall: 0.6972 - auc: 0.9475 - f1_score: 1.1149 - val_loss: 0.7010 - val_accuracy: 0.7287 - val_precision: 0.7456 - val_recall: 0.6755 - val_auc: 0.9383 - val_f1_score: 1.0638 - lr: 0.0010
# Epoch 3/50
# 318/318 [==============================] - 50s 157ms/step - loss: 0.4268 - accuracy: 0.8515 - precision: 0.8743 - recall: 0.8247 - auc: 0.9750 - f1_score: 1.2715 - val_loss: 0.6157 - val_accuracy: 0.7801 - val_precision: 0.8057 - val_recall: 0.7571 - val_auc: 0.9522 - val_f1_score: 1.1762 - lr: 0.0010
# Epoch 4/50
# 318/318 [==============================] - 49s 155ms/step - loss: 0.2745 - accuracy: 0.9052 - precision: 0.9174 - recall: 0.8924 - auc: 0.9886 - f1_score: 1.3548 - val_loss: 0.9128 - val_accuracy: 0.7624 - val_precision: 0.7794 - val_recall: 0.7518 - val_auc: 0.9293 - val_f1_score: 1.1476 - lr: 0.0010
# Epoch 5/50
# 318/318 [==============================] - 49s 155ms/step - loss: 0.1944 - accuracy: 0.9379 - precision: 0.9456 - recall: 0.9287 - auc: 0.9930 - f1_score: 1.4054 - val_loss: 0.6278 - val_accuracy: 0.8103 - val_precision: 0.8223 - val_recall: 0.7961 - val_auc: 0.9579 - val_f1_score: 1.2116 - lr: 0.0010
# Epoch 6/50
# 318/318 [==============================] - 50s 157ms/step - loss: 0.1362 - accuracy: 0.9578 - precision: 0.9601 - recall: 0.9529 - auc: 0.9961 - f1_score: 1.4339 - val_loss: 0.7139 - val_accuracy: 0.8156 - val_precision: 0.8164 - val_recall: 0.8121 - val_auc: 0.9530 - val_f1_score: 1.2269 - lr: 0.0010
# Epoch 7/50
# 318/318 [==============================] - 49s 154ms/step - loss: 0.1099 - accuracy: 0.9624 - precision: 0.9649 - recall: 0.9586 - auc: 0.9970 - f1_score: 1.4427 - val_loss: 0.8064 - val_accuracy: 0.8014 - val_precision: 0.8054 - val_recall: 0.7926 - val_auc: 0.9442 - val_f1_score: 1.2045 - lr: 0.0010
# Epoch 8/50
50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0093 - accuracy: 0.9951 - precision: 0.9955 - recall: 0.9941 - auc: 1.0000 - f1_score: 1.4913 - val_loss: 1.0151 - val_accuracy: 0.8528 - val_precision: 0.8544 - val_recall: 0.8528 - val_auc: 0.9450 - val_f1_score: 1.2846 - lr: 2.5000e-04
# Epoch 26/50
# 318/318 [==============================] - 47s 147ms/step - loss: 0.0086 - accuracy: 0.9953 - precision: 0.9959 - recall: 0.9949 - auc: 1.0000 - f1_score: 1.4930 - val_loss: 1.0359 - val_accuracy: 0.8475 - val_precision: 0.8490 - val_recall: 0.8475 - val_auc: 0.9473 - val_f1_score: 1.2772 - lr: 2.5000e-04
# Epoch 27/50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0080 - accuracy: 0.9953 - precision: 0.9963 - recall: 0.9949 - auc: 1.0000 - f1_score: 1.4933 - val_loss: 1.1227 - val_accuracy: 0.8404 - val_precision: 0.8419 - val_recall: 0.8404 - val_auc: 0.9395 - val_f1_score: 1.2667 - lr: 2.5000e-04
# Epoch 28/50
# 318/318 [==============================] - 47s 147ms/step - loss: 0.0073 - accuracy: 0.9957 - precision: 0.9965 - recall: 0.9955 - auc: 1.0000 - f1_score: 1.4939 - val_loss: 1.2046 - val_accuracy: 0.8387 - val_precision: 0.8387 - val_recall: 0.8387 - val_auc: 0.9353 - val_f1_score: 1.2630 - lr: 2.5000e-04
# Epoch 29/50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0079 - accuracy: 0.9955 - precision: 0.9957 - recall: 0.9951 - auc: 1.0000 - f1_score: 1.4931 - val_loss: 1.1674 - val_accuracy: 0.8369 - val_precision: 0.8399 - val_recall: 0.8369 - val_auc: 0.9370 - val_f1_score: 1.2626 - lr: 2.5000e-04
# Epoch 30/50
# 318/318 [==============================] - 46s 146ms/step - loss: 0.0096 - accuracy: 0.9945 - precision: 0.9953 - recall: 0.9935 - auc: 0.9999 - f1_score: 1.4916 - val_loss: 1.1330 - val_accuracy: 0.8404 - val_precision: 0.8419 - val_recall: 0.8404 - val_auc: 0.9369 - val_f1_score: 1.2664 - lr: 2.5000e-04
# Epoch 31/50
# 318/318 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9953 - precision: 0.9961 - recall: 0.9945 - auc: 1.0000 - f1_score: 1.4929
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 318/318 [==============================] - 46s 146ms/step - loss: 0.0069 - accuracy: 0.9953 - precision: 0.9961 - recall: 0.9945 - auc: 1.0000 - f1_score: 1.4929 - val_loss: 1.1295 - val_accuracy: 0.8422 - val_precision: 0.8419 - val_recall: 0.8404 - val_auc: 0.9384 - val_f1_score: 1.2666 - lr: 2.5000e-04
# Epoch 32/50
# 318/318 [==============================] - 46s 146ms/step - loss: 0.0083 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9949 - auc: 1.0000 - f1_score: 1.4926 - val_loss: 1.1406 - val_accuracy: 0.8387 - val_precision: 0.8387 - val_recall: 0.8387 - val_auc: 0.9373 - val_f1_score: 1.2630 - lr: 1.2500e-04
# Epoch 33/50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.
50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0072 - accuracy: 0.9961 - precision: 0.9963 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4939 - val_loss: 1.0374 - val_accuracy: 0.8475 - val_precision: 0.8475 - val_recall: 0.8475 - val_auc: 0.9449 - val_f1_score: 1.2760 - lr: 6.2500e-05
# Epoch 44/50
# 318/318 [==============================] - 46s 144ms/step - loss: 0.0078 - accuracy: 0.9959 - precision: 0.9959 - recall: 0.9949 - auc: 1.0000 - f1_score: 1.4930 - val_loss: 1.0414 - val_accuracy: 0.8511 - val_precision: 0.8511 - val_recall: 0.8511 - val_auc: 0.9457 - val_f1_score: 1.2812 - lr: 6.2500e-05
# Epoch 45/50
# 318/318 [==============================] - 46s 146ms/step - loss: 0.0077 - accuracy: 0.9955 - precision: 0.9963 - recall: 0.9951 - auc: 1.0000 - f1_score: 1.4926 - val_loss: 1.0551 - val_accuracy: 0.8475 - val_precision: 0.8475 - val_recall: 0.8475 - val_auc: 0.9447 - val_f1_score: 1.2760 - lr: 6.2500e-05
# Epoch 46/50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0071 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9947 - auc: 1.0000 - f1_score: 1.4925 - val_loss: 1.0589 - val_accuracy: 0.8475 - val_precision: 0.8490 - val_recall: 0.8475 - val_auc: 0.9438 - val_f1_score: 1.2771 - lr: 6.2500e-05
# Epoch 47/50
# 318/318 [==============================] - 46s 144ms/step - loss: 0.0064 - accuracy: 0.9963 - precision: 0.9968 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4944 - val_loss: 1.0786 - val_accuracy: 0.8475 - val_precision: 0.8475 - val_recall: 0.8475 - val_auc: 0.9428 - val_f1_score: 1.2760 - lr: 6.2500e-05
# Epoch 48/50
# 318/318 [==============================] - 46s 145ms/step - loss: 0.0063 - accuracy: 0.9959 - precision: 0.9965 - recall: 0.9957 - auc: 1.0000 - f1_score: 1.4941 - val_loss: 1.0755 - val_accuracy: 0.8440 - val_precision: 0.8440 - val_recall: 0.8440 - val_auc: 0.9454 - val_f1_score: 1.2708 - lr: 6.2500e-05
# Epoch 49/50
# 318/318 [==============================] - 48s 151ms/step - loss: 0.0076 - accuracy: 0.9951 - precision: 0.9959 - recall: 0.9949 - auc: 1.0000 - f1_score: 1.4930 - val_loss: 1.0720 - val_accuracy: 0.8440 - val_precision: 0.8440 - val_recall: 0.8440 - val_auc: 0.9454 - val_f1_score: 1.2708 - lr: 6.2500e-05
# Epoch 50/50
# 318/318 [==============================] - 48s 151ms/step - loss: 0.0080 - accuracy: 0.9941 - precision: 0.9943 - recall: 0.9941 - auc: 1.0000 - f1_score: 1.4913 - val_loss: 1.0652 - val_accuracy: 0.8493 - val_precision: 0.8493 - val_recall: 0.8493 - val_auc: 0.9439 - val_f1_score: 1.2786 - lr: 6.2500e-05

# %%
score = model.evaluate(x_test, y_test,  verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8309409618377686

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
